# %% [markdown]
# <a href="https://colab.research.google.com/github/Lanna-Maria/TCC-LannaMaria/blob/main/Opni%C3%B5es_Participantes_Lanna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from collections import Counter
import re
import nltk
from nltk.corpus import stopwords

# ===============================
# 0) DOWNLOAD DOS RECURSOS NLTK
# ===============================

nltk.download("stopwords")

stop_words = set(stopwords.words("portuguese"))

# ===============================
# 1) RESPOSTAS POSITIVAS E NEGATIVAS
# ===============================

respostasPositivas = [
   "O curso foi bastante produtivo, consegui tirar algumas dúvidas sobre o assunto. Me deu motivação para concluir os três semestre do curso técnico de informática. ",
    "Foi muito bom, consegui aprender bastante e a explicações foram excelentes. ",
    "Foi uma experiência ótima.",
    "foi tudo muito bem planejado.",
    "Tive como motivação a curiosidade por algoritmos.",
    "Gostei bastante do curso,pois a maneira como foi explicado ,também foi divertido e o mais importante:Aprendi e consegui entender o conteúdo.Dá próxima vez, não esqueçam de mim hein?Rsrs.Parabéns aos criadores,foi ótimo! ",
    "É um ótimo curso, aproveitei bastante tem uma maneira rápida e pratica de ensinar baseado no cotidiano isso é otimo foi uma oportunidade incrivel. ",
    "Adorei esse curso,achei fofo e criativo,gostaria de participar de outros nesse estilo. ",
    "Gostei muito do curso. Com ele pude aprender conteúdos que serão abordados no curso técnico em informática e estes foram dispostos de forma que facilitou bastante o entedimento sobre o assunto de uma forma bem divertida e descontraída. ",
    "Ter mais conhecimento Criatividade." ,
    "Eu gostei muito do curso, apesar de ser um pouco um curso rápido foi muito interresante. ",
    " O curso é muito importante pois compartilha conhecimentos relevantes e úteis, meus agradecimentos á equipe pelo tempo dedicado e pela realização desse trabalho, em algumas questões senti uma dificuldade de interpretar, porém com uma segunda lida consegui responder, aprendi muito com o curso e espero que outros possam também ter acesso a esse conteúdo. ",
    "Experiência boa, não tive dificuldade e minha motivação foi a busca pelo conhecimento.",
    "Minha experiência durante o curso foi boa, não tive dificuldades para resolver as questões sobre minha motivação para terminá-lo foi sempre meu interesse sobre aprender mais, e não tenho nenhuma crítica sobre o curso foi muito bem elaborado pelos tutores, parabéns! ",
    "Não tive dificuldade no aprendizado, curso ótimo e etc." ,
    "Foi ótimo ",
    "Foi bastante diversificado e divertido ",
    "Foi uma experiência muito positiva e interessante, estava muito motivado e consegui aprimorar mais o conhecimento sobre algoritmo. 8. Sem complicações, rápido e dinâmico.",
    "A experiencia foi muito boa ",
    "O curso foi muito bom e com uma temática interessante me senti muito motivado. Tirei muito conhecimento sobre os assuntos. ",
    "Gostei muito achei os Tutotores muito Rapidos sempre atentos para tira nossas duvidas.",
    "Gostei , achei muito interessante as perguntas foram difícil mesmo aparecendo facil precisava de muita atenção e eu confundi alguma resposta por nao presta atenção , mais de resto gostei bastante ! Por ser uma mulher em um curso técnico de informática eu gostei do conteúdo voltado para essa temática, e por ter sido um assunto proveitoso para formações futuras, como a faculdade de ciências da computação, foram assuntos interessantes aplicados de forma divertida e simples. ",
    "que independente da distância podemos ter uma aprendizagem igual a que temos em sala de aula. ",
    "Gostei bastante do curso, porque exercitou o raciocínio lógico e contribuiu para o engajamento da turma nesse 1° semestre! ",
    "foi muito bom" ,
    "o curso foi bem pratico principalmente por conseguir acessar em qualquer lugar e com facilidade, além de ser bem explicado ",
   "tive uma experiençia muito boa ",
   " em geral, uma boa experiencia. ",
    "Foi uma otima experiência ",
     "O curso foi muito bem explicado, vídeo aulas e slides criativos.",
    "Foi uma boa experiência, as perguntas treinam bem",
    "Foi uma boa experiência relacionada ao curso.",
    " O conteúdo foi muito bem elaborado e reproduzido e as autoras estão de parabéns!",
    "O curso foi ótimo!" ,
    "Além de aprender foi divertido.",
    "Foi muito bom, foi bastante interativo, facilitando na aprendizagem não só na leitura mais na pratica também.",
    "Gostei bastante do método a distância e do modo que o curso foi feito 5. Eu gostei, achei divertido.",
    "Muito bom.",
    "Muito bom e com certeza realizaria outros. Falta de prática com a internet mesmo . Com certeza mais conhecimento.",
    "Foi muito bom, facilidade em aprendizado.",
    "Foi bem legal a dinâmica aplicada, deu pra aproveitar bem os ensinamentos do curso 10. não tive aula a distancia.",
    "Curso bom pra  entender o pensamento computacional",
    "Minha experiência foi boa",
    "Nossa, a experiência foi incrível.",
    "Gostei, foi uma ótima experiência. É um ótimo curso que ajuda a aguçar o pensamento rápido e o raciocínio lógico!",
    "Muito boa, tutora muito simpática.",
    "Uma experiência boa,  Uma atividade qui refrescou mais a memória e se divertir um pouco dentro dela.",
    "Bom a minha experiência foi muito boa nunca havia feito esse curso a distância mais gostei bastante.",
    "Queria aprender mais para complementar meu curso técnico em informática,achei a experiência boa e lúdica,aprendi bem o conteúdo do curso.",
    " Achei o curso incrível, plataforma perfeita, o designer excelente, e o certificado maravilhoso! Que em breve, irei colocar no meu LinkedIn!",
    "Ah foi muito produtivo como eu disse, eu tive o apoio da tutora e da professora,e foi muito o desenvolvimento.",
]

respostasNegativas= [
  "ao longo do curso me desmotivei  a minha primeira nota não foi o que eu esperava e no teste final não estava com ânimo para continuar e fiquei sem interesse para tirar boa nota.",
"tive um pouco de dificuldade",
"o design da plataforma não foi fácil descobrir onde a gente se inscrevia no curso.",
"deveria existir mais interação nas atividades de fixação com algum colega.",
"a disciplina que se deve ter nos cursos a distância seja um fator de extrema relevância",
"algumas dificuldades em adaptações",
"alterar as questões do teste final, para não depender do quanto a pessoa se lembra das respostas anteriormente",
"poderia ter mais vídeos interativos.",
"não fiz o ensino a distância.",
"foi um pouco difícil."

]

# ===============================
# 2) FUNÇÃO DE PRÉ-PROCESSAMENTO
# ===============================

def preprocessar(respostas):
    palavras_total = []
    for resposta in respostas:
        texto = resposta.lower()

        # remove tudo que NÃO for letra ou espaço
        texto = re.sub(r"[^a-zA-Záéíóúâêîôûãõç\s]", "", texto)

        palavras = texto.split()

        # remove stopwords
        palavras = [p for p in palavras if p not in stop_words]

        palavras_total.extend(palavras)

    return Counter(palavras_total)

# ===============================
# 3) CONTAR PALAVRAS
# ===============================

freq1 = preprocessar(respostasPositivas)
freq2 = preprocessar(respostasNegativas)

top1 = freq1.most_common(10)
top2 = freq2.most_common(10)

pal1, count1 = zip(*top1)
pal2, count2 = zip(*top2)

# ===============================
# 4) GRÁFICO COMPARATIVO
# ===============================

plt.figure(figsize=(16, 6))

# ----- Grupo 1 -----
plt.subplot(1, 2, 1)
plt.bar(pal1, count1)
plt.xticks(rotation=45)
plt.title("Pontos Positivos")
plt.ylabel("Frequência")

# ----- Grupo 2 -----
plt.subplot(1, 2, 2)
plt.bar(pal2, count2, color="red")
plt.xticks(rotation=45)
plt.title("Pontos Negativos")

plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import string

# baixar recursos
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')


# listas originais
respostasPositivas = [ "O curso foi bastante produtivo, consegui tirar algumas dúvidas sobre o assunto. Me deu motivação para concluir os três semestre do curso técnico de informática. ",
    "Foi muito bom, consegui aprender bastante e a explicações foram excelentes. ",
    "Foi uma experiência ótima.",
    "foi tudo muito bem planejado.",
    "Tive como motivação a curiosidade por algoritmos.",
    "Gostei bastante do curso,pois a maneira como foi explicado ,também foi divertido e o mais importante:Aprendi e consegui entender o conteúdo.Dá próxima vez, não esqueçam de mim hein?Rsrs.Parabéns aos criadores,foi ótimo! ",
    "É um ótimo curso, aproveitei bastante tem uma maneira rápida e pratica de ensinar baseado no cotidiano isso é otimo foi uma oportunidade incrivel. ",
    "Adorei esse curso,achei fofo e criativo,gostaria de participar de outros nesse estilo. ",
    "Gostei muito do curso. Com ele pude aprender conteúdos que serão abordados no curso técnico em informática e estes foram dispostos de forma que facilitou bastante o entedimento sobre o assunto de uma forma bem divertida e descontraída. ",
    "Ter mais conhecimento Criatividade." ,
    "Eu gostei muito do curso, apesar de ser um pouco um curso rápido foi muito interresante. ",
    " O curso é muito importante pois compartilha conhecimentos relevantes e úteis, meus agradecimentos á equipe pelo tempo dedicado e pela realização desse trabalho, em algumas questões senti uma dificuldade de interpretar, porém com uma segunda lida consegui responder, aprendi muito com o curso e espero que outros possam também ter acesso a esse conteúdo. ",
    "Experiência boa, não tive dificuldade e minha motivação foi a busca pelo conhecimento.",
    "Minha experiência durante o curso foi boa, não tive dificuldades para resolver as questões sobre minha motivação para terminá-lo foi sempre meu interesse sobre aprender mais, e não tenho nenhuma crítica sobre o curso foi muito bem elaborado pelos tutores, parabéns! ",
    "Não tive dificuldade no aprendizado, curso ótimo e etc." ,
    "Foi ótimo ",
    "Foi bastante diversificado e divertido ",
    "Foi uma experiência muito positiva e interessante, estava muito motivado e consegui aprimorar mais o conhecimento sobre algoritmo. 8. Sem complicações, rápido e dinâmico.",
    "A experiencia foi muito boa ",
    "O curso foi muito bom e com uma temática interessante me senti muito motivado. Tirei muito conhecimento sobre os assuntos. ",
    "Gostei muito achei os Tutotores muito Rapidos sempre atentos para tira nossas duvidas.",
    "Gostei , achei muito interessante as perguntas foram difícil mesmo aparecendo facil precisava de muita atenção e eu confundi alguma resposta por nao presta atenção , mais de resto gostei bastante ! Por ser uma mulher em um curso técnico de informática eu gostei do conteúdo voltado para essa temática, e por ter sido um assunto proveitoso para formações futuras, como a faculdade de ciências da computação, foram assuntos interessantes aplicados de forma divertida e simples. ",
    "que independente da distância podemos ter uma aprendizagem igual a que temos em sala de aula. ",
    "Gostei bastante do curso, porque exercitou o raciocínio lógico e contribuiu para o engajamento da turma nesse 1° semestre! ",
    "foi muito bom" ,
    "o curso foi bem pratico principalmente por conseguir acessar em qualquer lugar e com facilidade, além de ser bem explicado ",
   "tive uma experiençia muito boa ",
   " em geral, uma boa experiencia. ",
    "Foi uma otima experiência ",
     "O curso foi muito bem explicado, vídeo aulas e slides criativos.",
    "Foi uma boa experiência, as perguntas treinam bem",
    "Foi uma boa experiência relacionada ao curso.",
    " O conteúdo foi muito bem elaborado e reproduzido e as autoras estão de parabéns!",
    "O curso foi ótimo!" ,
    "Além de aprender foi divertido.",
    "Foi muito bom, foi bastante interativo, facilitando na aprendizagem não só na leitura mais na pratica também.",
    "Gostei bastante do método a distância e do modo que o curso foi feito 5. Eu gostei, achei divertido.",
    "Muito bom.",
    "Muito bom e com certeza realizaria outros. Falta de prática com a internet mesmo . Com certeza mais conhecimento.",
    "Foi muito bom, facilidade em aprendizado.",
    "Foi bem legal a dinâmica aplicada, deu pra aproveitar bem os ensinamentos do curso 10. não tive aula a distancia.",
    "Curso bom pra  entender o pensamento computacional",
    "Minha experiência foi boa",
    "Nossa, a experiência foi incrível.",
    "Gostei, foi uma ótima experiência. É um ótimo curso que ajuda a aguçar o pensamento rápido e o raciocínio lógico!",
    "Muito boa, tutora muito simpática.",
    "Uma experiência boa,  Uma atividade qui refrescou mais a memória e se divertir um pouco dentro dela.",
    "Bom a minha experiência foi muito boa nunca havia feito esse curso a distância mais gostei bastante.",
    "Queria aprender mais para complementar meu curso técnico em informática,achei a experiência boa e lúdica,aprendi bem o conteúdo do curso.",
    " Achei o curso incrível, plataforma perfeita, o designer excelente, e o certificado maravilhoso! Que em breve, irei colocar no meu LinkedIn!",
    "Ah foi muito produtivo como eu disse, eu tive o apoio da tutora e da professora,e foi muito o desenvolvimento.",

]

respostasNegativas = [
   "ao longo do curso me desmotivei  a minha primeira nota não foi o que eu esperava e no teste final não estava com ânimo para continuar e fiquei sem interesse para tirar boa nota.",
"tive um pouco de dificuldade",
"o design da plataforma não foi fácil descobrir onde a gente se inscrevia no curso.",
"deveria existir mais interação nas atividades de fixação com algum colega.",
"a disciplina que se deve ter nos cursos a distância seja um fator de extrema relevância",
"algumas dificuldades em adaptações",
"alterar as questões do teste final, para não depender do quanto a pessoa se lembra das respostas anteriormente",
"poderia ter mais vídeos interativos.",
"não fiz o ensino a distância.",
"foi um pouco difícil."
    ]


# juntar tudo em um texto único
text1 = " ".join(respostasPositivas)
text2 = " ".join(respostasNegativas)

# stopwords
stop_words = set(stopwords.words("portuguese"))

def preprocess(text):
    # 1. tudo minúsculo
    text = text.lower()

    # 2. remover pontuação
    text = text.translate(str.maketrans("", "", string.punctuation))

    # 3. tokenizar
    tokens = word_tokenize(text)

    # 4. remover stopwords
    tokens = [w for w in tokens if w not in stop_words]

    # 5. juntar de volta para o WordCloud
    return " ".join(tokens)

# aplicar pré-processamento
clean1 = preprocess(text1)
clean2 = preprocess(text2)

print("\n====== TEXTO PROCESSADO (POSITIVOS) ======\n")
print(clean1[:500], "...")   # mostra os primeiros 500 caracteres

print("\n====== TEXTO PROCESSADO (NEGATIVOS) ======\n")
print(clean2[:500], "...")

# gerar WordCloud
wc1 = WordCloud(width=800, height=400, background_color="white").generate(clean1)
wc2 = WordCloud(width=800, height=400, background_color="white").generate(clean2)

# exibir imagens
plt.figure(figsize=(18,6))

plt.subplot(1,2,1)
plt.imshow(wc1, interpolation="bilinear")
plt.axis("off")
plt.title("Pontos Positivos")

plt.subplot(1,2,2)
plt.imshow(wc2, interpolation="bilinear")
plt.axis("off")
plt.title("Pontos Negativos")

plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ====== TEXTO PROCESSADO (POSITIVOS) ======
#
# curso bastante produtivo consegui tirar algumas dúvidas sobre assunto deu motivação concluir três semestre curso técnico informática bom consegui aprender bastante explicações excelentes experiência ótima tudo bem planejado motivação curiosidade algoritmos gostei bastante cursopois maneira explicado divertido importanteaprendi consegui entender conteúdodá próxima vez esqueçam mim heinrsrsparabéns criadoresfoi ótimo ótimo curso aproveitei bastante maneira rápida pratica ensinar baseado cotidiano  ...
#
# ====== TEXTO PROCESSADO (NEGATIVOS) ======
#
# ...
